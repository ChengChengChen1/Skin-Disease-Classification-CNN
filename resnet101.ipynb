# %%
# %load_ext autoreload
# %autoreload 2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

# TODO: Fill in the Google Drive path where you uploaded the assignment
# Example: If you create a 2020FA folder and put all the files under A1 folder, then '2020FA/A1'
# GOOGLE_DRIVE_PATH_AFTER_MYDRIVE = '2020FA/A1'
GOOGLE_DRIVE_PATH_AFTER_MYDRIVE = '/content/drive/MyDrive/Colab Notebooks/24年暑假科研/Skin_Conditions'
GOOGLE_DRIVE_PATH = os.path.join('drive', 'My Drive', GOOGLE_DRIVE_PATH_AFTER_MYDRIVE)
print(os.listdir(GOOGLE_DRIVE_PATH))
# Out:
# ['.DS_Store', 'Eczema', 'Carcinoma', 'Acne', 'Milia', 'Keratosis', 'Rosacea']

# %%
import numpy as np
import pandas as pd

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing import image_dataset_from_directory

dataset_dir = 'Skin_Conditions'
dataset = image_dataset_from_directory(
    GOOGLE_DRIVE_PATH,
    labels='inferred',
    label_mode='int',
    image_size=(224, 224),
    batch_size=32,
    shuffle=True
)

def split_dataset(dataset, train_size=0.8, val_size=0.1, test_size=0.1):
    total_size = len(dataset)
    train_end = int(total_size * train_size)
    val_end = train_end + int(total_size * val_size)

    train_dataset = dataset.take(train_end)
    val_dataset = dataset.skip(train_end).take(val_end - train_end)
    test_dataset = dataset.skip(val_end)

    return train_dataset, val_dataset, test_dataset

train_dataset, val_dataset, test_dataset = split_dataset(dataset)
# Out:
# Found 2394 files belonging to 6 classes.

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.applications import ResNet101

base_model = ResNet101(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
base_model.trainable = False
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(1024, activation='relu')(x)
x = Dropout(0.5)(x)
predictions = Dense(6, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=predictions)
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet101_weights_tf_dim_ordering_tf_kernels_notop.h5
# 171446536/171446536 [==============================] - 1s 0us/step

# %%
from tensorflow.keras.layers import RandomFlip, RandomRotation, RandomZoom

data_augmentation = tf.keras.Sequential([
    RandomFlip("horizontal"),
    RandomRotation(0.1),
    RandomZoom(0.1)
])

def augment_data(dataset):
    def augment(image, label):
        image = data_augmentation(image)
        return image, label

    return dataset.map(augment)

train_dataset = augment_data(train_dataset)

history = model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=20,
    batch_size=32
)
# Out:
# Epoch 1/20
# 60/60 [==============================] - 67s 955ms/step - loss: 1.3616 - accuracy: 0.5000 - val_loss: 0.7625 - val_accuracy: 0.7545
# Epoch 2/20
# 60/60 [==============================] - 56s 918ms/step - loss: 0.8055 - accuracy: 0.7276 - val_loss: 0.5184 - val_accuracy: 0.8259
# Epoch 3/20
# 60/60 [==============================] - 55s 908ms/step - loss: 0.6434 - accuracy: 0.7667 - val_loss: 0.4649 - val_accuracy: 0.8304
# Epoch 4/20
# 60/60 [==============================] - 55s 913ms/step - loss: 0.5427 - accuracy: 0.8078 - val_loss: 0.4041 - val_accuracy: 0.8661
# Epoch 5/20
# 60/60 [==============================] - 55s 907ms/step - loss: 0.5073 - accuracy: 0.8156 - val_loss: 0.3687 - val_accuracy: 0.8750
# Epoch 6/20
# 60/60 [==============================] - 56s 920ms/step - loss: 0.4468 - accuracy: 0.8453 - val_loss: 0.3546 - val_accuracy: 0.8616
# Epoch 7/20
# 60/60 [==============================] - 56s 915ms/step - loss: 0.4150 - accuracy: 0.8620 - val_loss: 0.4119 - val_accuracy: 0.8661
# Epoch 8/20
# 60/60 [==============================] - 55s 910ms/step - loss: 0.3542 - accuracy: 0.8833 - val_loss: 0.3183 - val_accuracy: 0.8973
# Epoch 9/20
# 60/60 [==============================] - 55s 910ms/step - loss: 0.3410 - accuracy: 0.8833 - val_loss: 0.4258 - val_accuracy: 0.8438
# Epoch 10/20
# 60/60 [==============================] - 55s 909ms/step - loss: 0.3256 - accuracy: 0.8880 - val_loss: 0.3276 - val_accuracy: 0.8571
# Epoch 11/20
# 60/60 [==============================] - 56s 924ms/step - loss: 0.2947 - accuracy: 0.9068 - val_loss: 0.3125 - val_accuracy: 0.8929
# Epoch 12/20
# 60/60 [==============================] - 55s 900ms/step - loss: 0.2729 - accuracy: 0.9135 - val_loss: 0.3496 - val_accuracy: 0.8571
# Epoch 13/20
# 60/60 [==============================] - 56s 923ms/step - loss: 0.2675 - accuracy: 0.9052 - val_loss: 0.2444 - val_accuracy: 0.8973
# Epoch 14/20
# 60/60 [==============================] - 55s 897ms/step - loss: 0.2572 - accuracy: 0.9115 - val_loss: 0.2696 - val_accuracy: 0.8973
# Epoch 15/20
# 60/60 [==============================] - 55s 899ms/step - loss: 0.2489 - accuracy: 0.9146 - val_loss: 0.2787 - val_accuracy: 0.8973
# Epoch 16/20
# 60/60 [==============================] - 54s 893ms/step - loss: 0.2218 - accuracy: 0.9266 - val_loss: 0.2807 - val_accuracy: 0.8839
# Epoch 17/20
# 60/60 [==============================] - 56s 917ms/step - loss: 0.2152 - accuracy: 0.9286 - val_loss: 0.2680 - val_accuracy: 0.8973
# Epoch 18/20
# 60/60 [==============================] - 54s 887ms/step - loss: 0.1897 - accuracy: 0.9344 - val_loss: 0.3229 - val_accuracy: 0.8705
# Epoch 19/20
# 60/60 [==============================] - 55s 906ms/step - loss: 0.1867 - accuracy: 0.9359 - val_loss: 0.2419 - val_accuracy: 0.9107
# Epoch 20/20
# 60/60 [==============================] - 54s 895ms/step - loss: 0.1925 - accuracy: 0.9359 - val_loss: 0.2231 - val_accuracy: 0.9152

# %%
test_loss, test_acc = model.evaluate(test_dataset)
print(f"Test Accuracy: {test_acc:.4f}")
# Out:
# 8/8 [==============================] - 10s 731ms/step - loss: 0.3386 - accuracy: 0.8640
# Test Accuracy: 0.8640

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report
# Predictions on test dataset
y_true = []
y_pred = []

for images, labels in test_dataset:
    preds = model.predict(images)
    y_true.extend(labels.numpy())
    y_pred.extend(np.argmax(preds, axis=1))

# Calculate precision, recall, F1-score, and accuracy
accuracy = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred, average='weighted')
recall = recall_score(y_true, y_pred, average='weighted')
f1 = f1_score(y_true, y_pred, average='weighted')

print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")

# Print the classification report for more details
print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=['Acne', 'Carcinoma', 'Eczema', 'Keratosis', 'Milia', 'Rosacea']))
# Out:
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 1s 799ms/step
# 1/1 [==============================] - 1s 773ms/step
# 1/1 [==============================] - 1s 784ms/step
# 1/1 [==============================] - 1s 786ms/step
# 1/1 [==============================] - 1s 775ms/step
# 1/1 [==============================] - 1s 891ms/step
# 1/1 [==============================] - 2s 2s/step
# Accuracy: 0.8800
# Precision: 0.8883
# Recall: 0.8800
# F1 Score: 0.8803
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Acne       0.81      0.90      0.85        48
#    Carcinoma       0.97      0.80      0.88        41
#       Eczema       0.97      0.81      0.88        47
#    Keratosis       0.90      0.97      0.93        36
#        Milia       0.87      0.92      0.89        37
#      Rosacea       0.80      0.90      0.85        41
#
#     accuracy                           0.88       250
#    macro avg       0.89      0.88      0.88       250
# weighted avg       0.89      0.88      0.88       250
